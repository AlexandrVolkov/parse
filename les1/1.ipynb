# %% [markdown]
# ### 1. Посмотреть документацию к API GitHub, разобраться как вывести список репозиториев для конкретного пользователя, сохранить JSON-вывод в файле *.json.

# %%
import requests
username = input('User Nickname:')
base_url = 'https://api.github.com'
getUserReposUrl = f'/users/{username}/repos'
response = requests.get(base_url + getUserReposUrl)
print('Список репозиториев:')
for i in response.json():
    print (i['name'])
# Out:
# User Nickname:AlexandrVolkov
# Список репозиториев:
# 5MinutePlank
# algebra
# mysql
# neural-style
# parse
# python

# %% [markdown]
# ### 2. Изучить список открытых API. Найти среди них любое, требующее авторизацию (любого типа). Выполнить запросы к нему, пройдя авторизацию. Ответ сервера записать в файл.

# %%
token = input('Введите token для GitHub API OAuth: ')
headers = {'Authorization': f'token {token}'}
response = requests.get(base_url, headers = headers)
username = input('User Nickname:')
response = requests.get(base_url + getUserReposUrl)
import json
with open('data.json', 'w') as outfile:
    json.dump(response.json(), outfile)
# Out:
# Введите token для GitHub API OAuthaf84b653e7be1cadd59acca292af6dea2f620258
# User Nickname:AlexandrVolkov

# %%
with open('data.json') as json_file:
    data = json.load(json_file)
print (data)
# Out:
# [{'id': 177555435, 'node_id': 'MDEwOlJlcG9zaXRvcnkxNzc1NTU0MzU=', 'name': '5MinutePlank', 'full_name': 'AlexandrVolkov/5MinutePlank', 'private': False, 'owner': {'login': 'AlexandrVolkov', 'id': 3992435, 'node_id': 'MDQ6VXNlcjM5OTI0MzU=', 'avatar_url': 'https://avatars3.githubusercontent.com/u/3992435?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/AlexandrVolkov', 'html_url': 'https://github.com/AlexandrVolkov', 'followers_url': 'https://api.github.com/users/AlexandrVolkov/followers', 'following_url': 'https://api.github.com/users/AlexandrVolkov/following{/other_user}', 'gists_url': 'https://api.github.com/users/AlexandrVolkov/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/AlexandrVolkov/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/AlexandrVolkov/subscriptions', 'organizations_url': 'https://api.github.com/users/AlexandrVolkov/orgs', 'repos_url': 'https://api.github.com/users/AlexandrVolkov/repos', 'events_url': 'https://a
# ...
